# %%
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from scipy import signal

df = pd.read_csv("CSV_Files/df.csv")

# %%
detrended = signal.detrend(df[df.Fault == 0].Vdc, type='linear')

# %%
pd.DataFrame(detrended).describe()
# Out:
#                   0
# count  1.410140e+05
# mean   6.426619e-14
# std    7.884656e-01
# min   -2.092908e+01
# 25%   -4.744148e-01
# 50%   -3.447739e-03
# 75%    4.830043e-01
# max    7.980207e+00

# %%
df[df.Fault == 0].Vdc
# Out:
# 0         147.949219
# 1         148.535156
# 2         147.656250
# 3         147.656250
# 4         147.363281
#              ...
# 141009    147.363281
# 141010    147.363281
# 141011    146.484375
# 141012    147.363281
# 141013    147.363281
# Name: Vdc, Length: 141014, dtype: float64
